# %% [markdown]
# ## Website
# https://www.price.com.hk/

# %%
# !pip install pyppeteer
# Out:
# ...
#      |████████████████████████████████| 1.2MB 9.1MB/s
# ...
#      |████████████████████████████████| 81kB 19.0MB/s
# ...
#   Created wheel for pyppeteer: filename=pyppeteer-0.0.25-cp36-none-any.whl size=78362 sha256=c108b2dd304de8f5c57640c61a0f3782b657907129778d809ab68ec7be6226a2
#   Stored in directory: /root/.cache/pip/wheels/34/e0/5d/070e22eceecf7ecd5fa4b86bbc18c1c7d0b90e02e9b57f35eb
# Successfully built pyppeteer
# ...

# %%
from pyppeteer import launch
import asyncio
