# %%
# !pip install pyppeteer
# Out:
# ...
#      |████████████████████████████████| 1.2MB 2.9MB/s
# ...
#      |████████████████████████████████| 81kB 29.1MB/s
# ...
#   Created wheel for pyppeteer: filename=pyppeteer-0.0.25-cp36-none-any.whl size=78362 sha256=36f56119ec61189e0d9a86f28e5ed677521a90e0c11b9f24b11794de171228d2
#   Stored in directory: /root/.cache/pip/wheels/34/e0/5d/070e22eceecf7ecd5fa4b86bbc18c1c7d0b90e02e9b57f35eb
# Successfully built pyppeteer
# ...

# %%
from pyppeteer import launch
from bs4 import BeautifulSoup
