# %%
from pyppeteer import launch
import asyncio
import nest_asyncio
from bs4 import BeautifulSoup as bs
import re
import time
import pandas as pd
import requests
import urllib.request

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 1000)
pd.set_option('display.max_colwidth', 100)

nest_asyncio.apply()

# %%
async def get_item(categroy: str):
    # browser = await launch()
    print("Setting up broswer for web page...")
    
    browser = await launch({
            "headless": False,
        })
    page = await browser.newPage()
    
    await page.setViewport({'width': 1920, 'height': 1080})
    await page.goto(categroy, {'timeout': 10000*30})
    return page, browser

# %%
dir_path = "./Suning/"
p = pd.read_csv(f"{dir_path}Products_Suning.csv")
c = pd.read_csv(f"{dir_path}Customers_Suning.csv")

# %%
c
# Out:
#        Unnamed: 0  Product Index Username  User Rate         Rate Date   Buyer Comment  Unnamed: 6  Unnamed: 7
# 0               0    10964124069    6***8          5  2019/06/20 17:25          發貨快,正品         NaN         NaN
# 1               1    10964124069    小***姐          5  2019/09/29 21:40  和之前iPadpro感覺一樣         NaN         NaN
# 2               2    10964124069    9***6          5  2019/09/21 19:54             非常快         NaN         NaN
# 3               3    10964124069    7***1          5  2019/10/15 19:06     买家没有填写评价内容！         NaN         NaN
# 4               4    10964124069    6***8          5  2019/10/14 12:42     买家没有填写评价内容！         NaN         NaN
# 5               5    10964124069    7***9          5  2019/10/13 15:11     买家没有填写评价内容！         NaN         NaN
# 6               6    10964124069    7***3          5  2019/10/11 16:22     买家没有填写评价内容！         NaN         NaN
# 7               7    10964124069    7***2          5  2019/10/09 19:56     买家没有填写评价内容！         NaN         NaN
# 8               8    10964124069    7***9          5  2019/10/08 14:26     买家没有填写评价内容！         NaN         NaN
# 9               9    10964124069    7***2          5  2019/10/07 17:01     买家没有填写评价内容！         NaN         NaN
# 10             10    10964124069    7***8          5  2019/10/07 15:10     买家没有填写评价内容！         NaN         NaN
# 11             11    10964124069    2***2          5  2019/10/06 20:51     买家没有填写评价内容！         NaN         NaN
# 12             12    10964124069    6***3          5  2019/10/06 20:06     买家没有填写评价内容！         NaN         NaN
# 13             13    10964124069    7***7          5  2019/10/06 20:00     买家没有填写评价内容！         NaN         NaN
# 14             14    10964124069    7***3          5  2019/10/05 17:21     买家没有填写评价内容！         NaN         NaN
# 15             15    10964124069    7***9          5  2019/10/05 17:07     买家没有填写评价内容！         NaN         NaN
# 16             16    10964124069    7***8          5  2019/10/04 16:52     买家没有填写评价内容！         NaN         NaN
# 17             17    10964124069    7***9          5  2019/10/02 19:08     买家没有填写评价内容！         NaN         NaN
# 18             18    10964124069    7***2          5  2019/10/02 17:11     买家没有填写评价内容！         NaN         NaN
# 19             19    10964124069    6***8          5  2019/10/01 21:06     买家没有填写评价内容！         NaN         NaN
# 20             20    10964124069    6***8          5  2019/10/01 21:01     买家没有填写评价内容！         NaN         NaN
# 21             21    10964124069    6***1          5  2019/10/01 14:36     买家没有填写评价内容！         NaN         NaN
# 49153       49153    10674060101    7***1          5  2019/04/12 20:40     买家没有填写评价内容！         NaN         NaN
# 49154       49154    10674060101    7***1          5  2019/04/12 20:35     买家没有填写评价内容！         NaN         NaN
# 49155       49155    10674060101    7***6          5  2019/04/12 19:15     买家没有填写评价内容！         NaN         NaN
# 49156       49156    10674060101    6***6          5  2019/04/12 16:55     买家没有填写评价内容！         NaN         NaN
# 49157       49157    10674060101    6***6          5  2019/04/12 16:40     买家没有填写评价内容！         NaN         NaN
# 49158       49158    10674060101    7***2          5  2019/04/12 11:10     买家没有填写评价内容！         NaN         NaN
# 49159       49159    10674060101    7***8          5  2019/04/12 10:55     买家没有填写评价内容！         NaN         NaN
# 49160       49160    10674060101    6***9          5   2019/04/12 6:16     买家没有填写评价内容！         NaN         NaN
# 49161       49161    10674060101    7***7          5  2019/04/11 15:50     买家没有填写评价内容！         NaN         NaN
#
# [49162 rows x 8 columns]

# %%
filtered = p.sort_values(['total_comment'], ascending=False).groupby(['product_type']).head(9)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-1350a7da7585> in <module>
# ----> 1 filtered = p.sort_values(['total_comment'], ascending=False).groupby(['product_type']).head(9)
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position)
#    4419             by = by[0]
#    4420             k = self._get_label_or_level_values(by, axis=axis,
# -> 4421                                                 stacklevel=stacklevel)
#    4422
#    4423             if isinstance(ascending, (tuple, list)):
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/generic.py in _get_label_or_level_values(self, key, axis, stacklevel)
#    1380             values = self.axes[axis].get_level_values(key)._values
#    1381         else:
# -> 1382             raise KeyError(key)
#    1383
#    1384         # Check for duplicates
#
# KeyError: 'total_comment'

# %%
filtered
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-8adf3a7c513e> in <module>
# ----> 1 filtered
#
# NameError: name 'filtered' is not defined

# %%
async def get_imgs():
    for index, row in filtered.iterrows():
        print(f"Processing product {index}")
        p_type = row['product_type'].replace(' ', '_')
        p_name = row['product_name'].replace(' ', '_')
        p_sales = str(row['total_comment'])
        p_url = row['website']

        page, browser = asyncio.get_event_loop().run_until_complete(get_item(p_url))
        source = bs(await page.content(), 'lxml').prettify()

        img_regex = re.compile(r'src="(//imgservice.suning.cn/\S+/\S+/\S+/\S+.jpg_800w_800h_4e)"/>')
        img_url = re.findall(img_regex, source)[0]
        img_path = f"{dir_path}Top-Ten-Img/{p_type}-{p_sales}.jpg"

        urllib.request.urlretrieve(f"http:{img_url}", img_path)

        print(f"Saved image in {img_path}\n")

        await browser.close()

# %%
asyncio.get_event_loop().run_until_complete(get_imgs())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-acfc246942c5> in <module>
# ----> 1 asyncio.get_event_loop().run_until_complete(get_imgs())
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/asyncio/base_events.py in run_until_complete(self, future)
#     471             raise RuntimeError('Event loop stopped before Future completed.')
#     472
# --> 473         return future.result()
#     474
#     475     def stop(self):
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/asyncio/tasks.py in _step(***failed resolving arguments***)
#     178                 # We use the `send` method directly, because coroutines
#     179                 # don't have `__iter__` and `__next__` methods.
# --> 180                 result = coro.send(None)
#     181             else:
#     182                 result = coro.throw(exc)
#
# <ipython-input-16-425a7cd37500> in get_imgs()
#       1 async def get_imgs():
# ----> 2     for index, row in filtered.iterrows():
#       3         print(f"Processing product {index}")
#       4         p_type = row['product_type'].replace(' ', '_')
#       5         p_name = row['product_name'].replace(' ', '_')
#
# NameError: name 'filtered' is not defined
